# %%
# Langkah 1: Install Dependencies
# Jalankan ini sekali di awal notebook
# %pip install -U ragas langchain langchain-community datasets tqdm nohup
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement nohup (from versions: none)
# ERROR: No matching distribution found for nohup
# Note: you may need to restart the kernel to use updated packages.

# %%
# Langkah 2: Install & Jalankan Ollama Server (full lokal)
# Jalankan ini setiap runtime baru atau kalau server mati
# !curl -fsSL https://ollama.com/install.sh | sh  # install kalau belum
# !nohup ollama serve > ollama.log 2>&1 &  # jalankan di background
# !sleep 10  # tunggu 10 detik agar server hidup
# Out:
# >>> Stopping running Ollama instance...
# >>> Removing existing Ollama installation...
# >>> Downloading Ollama for macOS...
# ######################################################################## 100.0%                                                  13.8%0%                                              20.1%                                                       20.2%               20.5%                                  23.6%       29.6%                                              31.6%                                                36.1%       40.2%######                         69.1%################################                81.2%########################              84.5%###################################################          88.9%#####################################       93.4%
# >>> Installing Ollama to /Applications...
# >>> Starting Ollama...
# >>> Install complete. You can now run 'ollama'.

# %%
# Cek server hidup
# !curl http://localhost:11434
# Out:
# Ollama is running

# %%
# !ollama pull qwen2.5:7b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏  16 KB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏ 468 KB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏ 705 KB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏ 868 KB/4.7 GB                  pulling manifest
# pulling 2bada8a74506:   0% ▕                  ▏ 963 KB/4.7 GB                  pulling manifest
# ...

# %%
# Langkah 3: Import & Setup
from datasets import load_dataset
from ragas import evaluate
from ragas.metrics import Faithfulness, AnswerRelevancy, ContextPrecision, ContextRecall, AnswerCorrectness
from langchain_community.chat_models import ChatOllama

# Judge LLM: Ollama lokal
judge_llm = ChatOllama(
    model="qwen2.5:7b", # ganti dengan yang sudah di-pull, seperti qwen2.5:7b kalau lambat
    temperature=0.0, # deterministic untuk scoring akurat
    num_ctx=4096, # cukup untuk judge task
    base_url="http://localhost:11434" # endpoint default
)
